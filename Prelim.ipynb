# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

import video

# %%
vid = video.Video("ORBCOMM-2 Full Launch Webcast-O5bTbVbe4e4.webm")

# %%
vid.f[41480]
# Out:
# <Frame: 1080x1920 px, frame no. 41481 (t=1382.70)>

# %%
vid.f[46338]
# Out:
# <Frame: 1080x1920 px, frame no. 46339 (t=1544.63)>

# %%
vid.f[59000]
# Out:
# <Frame: 1080x1920 px, frame no. 59001 (t=1966.70)>

# %%
t = (59000 - 41480) / vid.fps
divmod(t, 60)
# Out:
# (9.0, 44.0)

# %% [markdown]
# minimal time/frame skew (at least reported)

# %%
frame = vid.f[41480]
frame.data.shape
# Out:
# (1080, 1920)

# %%
alt = (slice(210, 240), slice(1768, 1845))
vel = (slice(210, 240), slice(1560, 1670))
time = (slice(32, 62), slice(1510, 1750))

plt.imshow(frame.data[time])

# %%
plt.imshow(vid.f[46339].data[time])

# %%
im = vid.f[43480].data[time]
plt.imshow(im)

# %%
np.mean(im)
# Out:
# 0.1860376

# %%
threshold = np.mean(im)
threshold = np.percentile(im, 85)
threshold
# Out:
# 0.3490196168422699

# %%
imt = im > threshold
plt.imshow(imt)

# %%
plt.plot(imt.sum(axis=0))
